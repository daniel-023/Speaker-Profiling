# %% [markdown]
# # Singapore Speaker Prediction with WavLM
# We perform demographic profiling on a subset of the NSC Part 3 (containing 30 speakers) using WavLM features extracted from 10-second audio clips. Classification performance is evaluated across **gender**, **age**, **ethnicity**, and **education** categories.

# %% [markdown]
# ### Setup and Imports

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pydub in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.25.1)
# Requirement already satisfied: transformers in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (4.50.1)
# Requirement already satisfied: librosa in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: torch in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.6.0)
# Requirement already satisfied: pandas in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: openpyxl in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: scikit-learn in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (3.10.1)
# Requirement already satisfied: seaborn in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (0.13.2)
# Requirement already satisfied: imblearn in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.0)
# Requirement already satisfied: plotly in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: filelock in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: requests in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from transformers->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (0.61.0)
# Requirement already satisfied: scipy>=1.6.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (1.15.2)
# Requirement already satisfied: joblib>=1.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from librosa->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: networkx in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from torch->-r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from torch->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from torch->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from torch->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from sympy==1.13.1->torch->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2025.2)
# Requirement already satisfied: et-xmlfile in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from openpyxl->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from scikit-learn->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from matplotlib->-r requirements.txt (line 8)) (3.2.3)
# Requirement already satisfied: imbalanced-learn in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from imblearn->-r requirements.txt (line 10)) (0.13.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from plotly->-r requirements.txt (line 11)) (1.33.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 3)) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from pooch>=1.1->librosa->-r requirements.txt (line 3)) (4.3.6)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from requests->transformers->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: cffi>=1.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from imbalanced-learn->imblearn->-r requirements.txt (line 10)) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from jinja2->torch->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/asp/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r requirements.txt (line 3)) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoFeatureExtractor, AutoModel
import torch
import librosa
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Load Metadata and Audio Paths

# %%
speaker_df = pd.read_excel("Speakers (Part 3).xlsx")
clip_directory = Path("dataset/clips")

# %% [markdown]
# ### Load `WavLM Base+` Model

# %%
model = "microsoft/wavlm-base-plus"
feature_extractor = AutoFeatureExtractor.from_pretrained(model)
model = AutoModel.from_pretrained(model)

# %% [markdown]
# ### Define Batch Feature Extraction Function

# %%
def extract_features_batch(batch_audio_arrays):

    # Extract embeddings 
    inputs = feature_extractor(batch_audio_arrays,
                               sampling_rate=16000,
                               return_tensors='pt' # Convert to PyTorch tensors
    )
    inputs["attention_mask"] = inputs["attention_mask"].bool()

    model.eval()
    with torch.no_grad(): # Disable gradient tracking
        outputs = model(**inputs)

    # Mean pooling
    embeddings = outputs.last_hidden_state.mean(dim=1) 
    
    return embeddings.cpu().numpy()

# %% [markdown]
# ### Extract Speech Embeddings and Labels

# %%
records = []
batch_audio_arrays = []
batch_metadata = []
clip_paths = list(clip_directory.rglob('*.wav'))

batch_size = 16

for wav_file in clip_paths:
    speaker_id = int(wav_file.stem.split('_')[0])
    row = speaker_df[speaker_df["Speaker ID"] == speaker_id]

    wav, _ = librosa.load(wav_file, sr=16000)
    batch_audio_arrays.append(wav)
    batch_metadata.append({
        "speaker_id": speaker_id,
        "age": row["Age"].values[0],
        "gender": row["Gender"].values[0],
        "ethnicity": row["Ethnicity"].values[0],
        "education": row["Education"].values[0],
        "clip_path": str(wav_file)
    })
    
    if len(batch_audio_arrays) == batch_size:
        embeddings = extract_features_batch(batch_audio_arrays)

        for i in range(len(batch_metadata)):
            record = batch_metadata[i]
            record["embeddings"] = embeddings[i]
            records.append(record)

        # Clear batch
        batch_audio_arrays = []
        batch_metadata = []

# Remaining data in final batch
if batch_audio_arrays:
    embeddings = extract_features_batch(batch_audio_arrays)
    for i in range(len(batch_metadata)):
        record = batch_metadata[i]
        record["embeddings"] = embeddings[i]
        records.append(record)
# Out:
# /opt/miniconda3/envs/asp/lib/python3.10/site-packages/torch/nn/functional.py:5962: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(

# %% [markdown]
# ### Create DataFrame
# Some typos were corrected: 'PLSE' to 'PSLE' and 'BACHELOR' to 'BACHELORS'

# %%
df = pd.DataFrame(records)
df["education"] = df["education"].replace({'PLSE': 'PSLE'})
df["education"] = df["education"].replace({'BACHELOR': 'BACHELORS'})
education_order = ['PSLE', 'N-LEVEL', 'O-LEVEL', 'A-LEVEL', 'DIPLOMA', 'BACHELORS', 'POSTGRADUATE']
df["education"] = pd.Categorical(df["education"], categories=education_order, ordered=True)
age_order = ['1X', '2X', '3X', '4X', '5X', '6X']
df["age"] = pd.Categorical(df["age"], categories=age_order, ordered=True)

# Save metadata and embeddings
embedding_matrix = np.stack(df["embeddings"].values)
np.save("dataset/embeddings.npy", embedding_matrix)
df_metadata = df.drop(columns=["embeddings"])
df_metadata.to_csv("dataset/metadata.csv", index=False)

# %% [markdown]
# ### Load saved data

# %%
embeddings = np.load("dataset/embeddings.npy")
df = pd.read_csv('dataset/metadata.csv')
df["embeddings"] = list(embeddings)

# %% [markdown]
# ### Speaker-Level Pooling (not used)

# %%
new_df = pd.DataFrame(df.groupby('speaker_id').first())
new_df['embeddings'] = df.groupby('speaker_id')['embeddings'].mean()
new_df.head()
# Out:
#            age gender ethnicity education  \
# speaker_id
# 862025      2X      M     MALAY   A-LEVEL
# 862026      1X      F   CHINESE   O-LEVEL
# 862027      1X      M   CHINESE   DIPLOMA
# 862029      2X      M   CHINESE      None
# 862031      1X      M     MALAY   O-LEVEL
#
#                                               clip_path  \
# speaker_id
# 862025       dataset/clips/00862025/00862025_clip_9.wav
# 862026      dataset/clips/00862026/00862026_clip_14.wav
# 862027       dataset/clips/00862027/00862027_clip_8.wav
# 862029      dataset/clips/00862029/00862029_clip_16.wav
# 862031      dataset/clips/00862031/00862031_clip_20.wav
#
#                                                    embeddings
# speaker_id
# 862025      [-0.039310625195503233, 0.01289312243461609, -...
# 862026      [-0.03171645104885101, 0.014338816702365875, -...
# 862027      [-0.03399556577205658, 0.018094468116760253, -...
# 862029      [-0.04430921077728271, 0.019183820486068724, -...
# 862031      [-0.026571100950241087, 0.017916209995746613, ...

# %% [markdown]
# ### Data Exploration

# %%
sns.set_theme(style="whitegrid")

plot_df = df.groupby("speaker_id", as_index=False).first()

sns.catplot(
    data=plot_df,
    kind="count",
    x="ethnicity",
    hue="gender",
    col="age",          
    height=4,
    aspect=1
)

plt.suptitle("Speaker Distribution by Ethnicity, Gender, and Age", y=1.05)
plt.show()

# %%
sns.countplot(plot_df, x="gender")
plt.title('Speaker Distribution by Gender')
plt.xlabel("Gender")
plt.ylabel("Number of Speakers")
# Out:
# Text(0, 0.5, 'Number of Speakers')

# %%
sns.countplot(plot_df, x="education")
plt.title("Speaker Distribution by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Number of Speakers")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(np.vstack(df['embeddings']))

fig = px.scatter(
    x=X_tsne[:, 0],
    y=X_tsne[:, 1],
    color=df['ethnicity'],
    title="t-SNE visualization of WavLM embeddings (by Ethnicity)"
)
fig.update_traces(marker=dict(size=5))
fig.show()

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(np.vstack(df['embeddings']))

fig = px.scatter(
    x=X_tsne[:, 0],
    y=X_tsne[:, 1],
    color=df['gender'],
    title="t-SNE visualization of WavLM embeddings (by Gender)"
)
fig.update_traces(marker=dict(size=5))
fig.show()

# %% [markdown]
# ### Define Classification Function

# %%
def run_classification(category, use_pca = False):
    temp_df = df.copy()
    
    if category == "age":
        valid_labels = ["1X", "2X", "3X", "4X"]
    elif category == "education":
        valid_labels = ["N-LEVEL", "O-LEVEL", "A-LEVEL", "DIPLOMA"]
    else:
        valid_labels = df[category].unique().tolist()
    
    temp_df = temp_df[temp_df[category].isin(valid_labels)]
    
    # Group to get one label per speaker
    speaker_labels = temp_df.groupby("speaker_id")[category].first()
    speaker_pool = speaker_labels.index.tolist()

    train_speakers, test_speakers = train_test_split(speaker_pool, test_size=0.2, stratify=speaker_labels, random_state=42)
    train_df = temp_df[temp_df["speaker_id"].isin(train_speakers)]    
    test_df = temp_df[temp_df["speaker_id"].isin(test_speakers)]   
    
    X_train = np.vstack(train_df["embeddings"])
    X_test = np.vstack(test_df["embeddings"])

    enc = LabelEncoder()
    y_train = enc.fit_transform(train_df[category])
    y_test = enc.transform(test_df[category])
    
    if use_pca:
        pca = PCA(n_components=150)
        X_train = pca.fit_transform(X_train)
        X_test = pca.transform(X_test)
    
    smote = SMOTE(random_state=42)
    X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

    classifiers = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "Random Forest": RandomForestClassifier(),
        "Naive Bayes": GaussianNB(),
        "SVM": SVC(),
        "MLP": MLPClassifier(hidden_layer_sizes=(256,), max_iter=500)
    }

    for name, clf in classifiers.items():
        print(f"\n === {name} ===")
        clf.fit(X_train_bal, y_train_bal)
        y_pred = clf.predict(X_test)

        target_names = enc.classes_

        print(classification_report(y_test, y_pred, target_names=target_names))
        cm = confusion_matrix(y_test, y_pred)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
        disp.plot(cmap='Blues')
        plt.title(f"{name} - {category} Confusion Matrix")
        plt.show()

# %% [markdown]
# ### Gender Classification

# %%
run_classification("gender")
# Out:
#  === Logistic Regression ===
#               precision    recall  f1-score   support
#
#            F       0.93      0.97      0.95       100
#            M       0.98      0.95      0.96       140
#
#     accuracy                           0.96       240
#    macro avg       0.96      0.96      0.96       240
# weighted avg       0.96      0.96      0.96       240
#  === Random Forest ===
#               precision    recall  f1-score   support
#
#            F       0.92      0.92      0.92       100
#            M       0.94      0.94      0.94       140
#
#     accuracy                           0.93       240
#    macro avg       0.93      0.93      0.93       240
# weighted avg       0.93      0.93      0.93       240
#  === Naive Bayes ===
#               precision    recall  f1-score   support
#
#            F       0.83      0.76      0.79       100
#            M       0.84      0.89      0.86       140
#
#     accuracy                           0.83       240
#    macro avg       0.83      0.82      0.83       240
# weighted avg       0.83      0.83      0.83       240
#  === SVM ===
#               precision    recall  f1-score   support
#
#            F       0.95      0.99      0.97       100
#            M       0.99      0.96      0.98       140
#
#     accuracy                           0.97       240
#    macro avg       0.97      0.98      0.97       240
# weighted avg       0.98      0.97      0.98       240
#  === MLP ===
#               precision    recall  f1-score   support
#
#            F       0.98      0.99      0.99       100
#            M       0.99      0.99      0.99       140
#
#     accuracy                           0.99       240
#    macro avg       0.99      0.99      0.99       240
# weighted avg       0.99      0.99      0.99       240

# %% [markdown]
# ### Age Classification

# %%
run_classification("age", use_pca=True)
# Out:
#  === Logistic Regression ===
#               precision    recall  f1-score   support
#
#           1X       0.77      0.62      0.69       100
#           2X       0.58      0.45      0.51       100
#           3X       0.18      0.55      0.28        20
#           4X       0.68      0.75      0.71        20
#
#     accuracy                           0.55       240
#    macro avg       0.55      0.59      0.55       240
# weighted avg       0.63      0.55      0.58       240
#  === Random Forest ===
#               precision    recall  f1-score   support
#
#           1X       0.60      0.55      0.57       100
#           2X       0.51      0.71      0.60       100
#           3X       0.00      0.00      0.00        20
#           4X       0.50      0.15      0.23        20
#
#     accuracy                           0.54       240
#    macro avg       0.40      0.35      0.35       240
# weighted avg       0.51      0.54      0.51       240
#  === Naive Bayes ===
#               precision    recall  f1-score   support
#
#           1X       0.78      0.62      0.69       100
#           2X       0.55      0.81      0.66       100
#           3X       0.00      0.00      0.00        20
#           4X       0.50      0.10      0.17        20
#
#     accuracy                           0.60       240
#    macro avg       0.46      0.38      0.38       240
# weighted avg       0.60      0.60      0.58       240
#  === SVM ===
#               precision    recall  f1-score   support
#
#           1X       0.75      0.61      0.67       100
#           2X       0.56      0.75      0.64       100
#           3X       0.31      0.20      0.24        20
#           4X       1.00      0.55      0.71        20
#
#     accuracy                           0.63       240
#    macro avg       0.65      0.53      0.57       240
# weighted avg       0.65      0.63      0.63       240
#  === MLP ===
#               precision    recall  f1-score   support
#
#           1X       0.81      0.62      0.70       100
#           2X       0.54      0.65      0.59       100
#           3X       0.14      0.20      0.17        20
#           4X       0.86      0.60      0.71        20
#
#     accuracy                           0.60       240
#    macro avg       0.59      0.52      0.54       240
# weighted avg       0.64      0.60      0.61       240

# %% [markdown]
# ### Ethnicity Classification

# %%
run_classification("ethnicity")
# Out:
#  === Logistic Regression ===
#               precision    recall  f1-score   support
#
#      CHINESE       0.63      0.99      0.77        80
#       INDIAN       0.75      0.65      0.70        80
#        MALAY       0.85      0.49      0.62        80
#
#     accuracy                           0.71       240
#    macro avg       0.74      0.71      0.70       240
# weighted avg       0.74      0.71      0.70       240
#  === Random Forest ===
#               precision    recall  f1-score   support
#
#      CHINESE       0.58      0.97      0.73        80
#       INDIAN       0.62      0.49      0.55        80
#        MALAY       0.74      0.39      0.51        80
#
#     accuracy                           0.62       240
#    macro avg       0.64      0.62      0.59       240
# weighted avg       0.64      0.62      0.59       240
#  === Naive Bayes ===
#               precision    recall  f1-score   support
#
#      CHINESE       0.57      1.00      0.72        80
#       INDIAN       0.67      0.23      0.34        80
#        MALAY       0.54      0.49      0.51        80
#
#     accuracy                           0.57       240
#    macro avg       0.59      0.57      0.52       240
# weighted avg       0.59      0.57      0.52       240
#  === SVM ===
#               precision    recall  f1-score   support
#
#      CHINESE       0.66      1.00      0.79        80
#       INDIAN       0.75      0.65      0.70        80
#        MALAY       0.84      0.51      0.64        80
#
#     accuracy                           0.72       240
#    macro avg       0.75      0.72      0.71       240
# weighted avg       0.75      0.72      0.71       240
#  === MLP ===
#               precision    recall  f1-score   support
#
#      CHINESE       0.61      0.96      0.74        80
#       INDIAN       0.63      0.46      0.53        80
#        MALAY       0.74      0.50      0.60        80
#
#     accuracy                           0.64       240
#    macro avg       0.66      0.64      0.62       240
# weighted avg       0.66      0.64      0.62       240

# %% [markdown]
# ### Education Classification

# %%
run_classification("education")
# Out:
#  === Logistic Regression ===
#               precision    recall  f1-score   support
#
#      A-LEVEL       0.29      0.33      0.31        40
#      DIPLOMA       0.47      0.44      0.45        80
#      N-LEVEL       0.45      0.53      0.48        40
#      O-LEVEL       0.35      0.32      0.33        60
#
#     accuracy                           0.40       220
#    macro avg       0.39      0.40      0.39       220
# weighted avg       0.40      0.40      0.40       220
#  === Random Forest ===
#               precision    recall  f1-score   support
#
#      A-LEVEL       0.41      0.28      0.33        40
#      DIPLOMA       0.42      0.64      0.50        80
#      N-LEVEL       0.62      0.33      0.43        40
#      O-LEVEL       0.36      0.30      0.33        60
#
#     accuracy                           0.42       220
#    macro avg       0.45      0.38      0.40       220
# weighted avg       0.44      0.42      0.41       220
#  === Naive Bayes ===
#               precision    recall  f1-score   support
#
#      A-LEVEL       0.33      0.35      0.34        40
#      DIPLOMA       0.54      0.40      0.46        80
#      N-LEVEL       0.49      0.50      0.49        40
#      O-LEVEL       0.31      0.40      0.35        60
#
#     accuracy                           0.41       220
#    macro avg       0.42      0.41      0.41       220
# weighted avg       0.43      0.41      0.41       220
#  === SVM ===
#               precision    recall  f1-score   support
#
#      A-LEVEL       0.33      0.35      0.34        40
#      DIPLOMA       0.48      0.47      0.48        80
#      N-LEVEL       0.46      0.45      0.46        40
#      O-LEVEL       0.34      0.33      0.34        60
#
#     accuracy                           0.41       220
#    macro avg       0.40      0.40      0.40       220
# weighted avg       0.41      0.41      0.41       220
#  === MLP ===
#               precision    recall  f1-score   support
#
#      A-LEVEL       0.33      0.25      0.29        40
#      DIPLOMA       0.43      0.68      0.52        80
#      N-LEVEL       0.38      0.25      0.30        40
#      O-LEVEL       0.47      0.30      0.37        60
#
#     accuracy                           0.42       220
#    macro avg       0.41      0.37      0.37       220
# weighted avg       0.42      0.42      0.40       220
